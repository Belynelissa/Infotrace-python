# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib as mlt

# %%
df =pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# Exploratory data analysis

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.tenure
# Out:
# 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7038    24
# 7039    72
# 7040    11
# 7041     4
# 7042    66
# Name: tenure, Length: 7043, dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df = df.rename(columns={'customerID':'CustomerID' , 'gender':'Gender' , 'tenure':'Tenure'})

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'Tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Graphs

# %%
df
# Out:
#       CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
dummy = pd.get_dummies(df['Gender'])
dummy.head()
# Out:
#    Female   Male
# 0    True  False
# 1   False   True
# 2   False   True
# 3   False   True
# 4    True  False

# %%
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})

# %%
df['Churn'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
df.head()
# Out:
#    CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85     0
# 1               Mailed check          56.95        1889.5     0
# 2               Mailed check          53.85        108.15     1
# 3  Bank transfer (automatic)          42.30       1840.75     0
# 4           Electronic check          70.70        151.65     1
#
# [5 rows x 21 columns]

# %%
import seaborn as sns

# %%
sns.countplot(x='Churn', data =df, hue ='Churn')
plt.title('Churn count', fontsize=16, fontweight='bold', color='black', loc='center')
plt.show()

# %%
sns.countplot(x='Gender', data =df, hue='Churn')
plt.title('Churn by gender', fontsize =16, fontweight='bold', color='black', loc='center')
plt.show()

# %%
sns.countplot(x='InternetService', hue='Churn', data =df)
plt.title('Churn by Internet Service', fontsize=15, fontweight='bold', color='black', loc='center')
plt.show()

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title('Churn by Contract', fontsize=16, fontweight='bold', color='black', loc='center')
plt.show()

# %%
import scipy.stats as stats

# %% [markdown]
# # Chi-square test of independence

# %%
import pandas as pd

# %%
import scipy.stats as stats

# %%
import pandas as pd  # Import pandas for data handling
import scipy.stats as stats  # Import scipy for statistical tests

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert all columns to strings (ensures categorical columns are treated correctly)
df = df.astype(str)

# Step 3: Identify categorical columns (ignore 'Churn' because it's the target variable)
categorical_columns = df.select_dtypes(include=['object']).columns  # Select text/categorical columns
categorical_columns = [col for col in categorical_columns if col != 'Churn']  # Remove 'Churn' itself

# Step 4: Perform Chi-Square Test for each categorical column
print("Chi-Square Test Results for Churn:\n")

for col in categorical_columns:
    # Step 5: Create a contingency table (counts of each category vs. Churn)
    contingency_table = pd.crosstab(df[col], df['Churn'])

    # Step 6: Apply Chi-Square Test
    chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)

    # Step 7: Print results in a simple format
    print(f"Feature: {col}")
    print(f"Chi-Square Score: {chi2:.2f}, p-value: {p_value:.4f}")

    # Step 8: Interpret the results
    if p_value < 0.05:
        print("-> Significant relationship with Churn (p < 0.05)\n")
    else:
        print("-> No significant relationship with Churn\n")
# Out:
# Chi-Square Test Results for Churn:
#
# Feature: customerID
# Chi-Square Score: 7043.00, p-value: 0.4944
# -> No significant relationship with Churn
#
# Feature: gender
# Chi-Square Score: 0.48, p-value: 0.4866
# -> No significant relationship with Churn
#
# Feature: SeniorCitizen
# Chi-Square Score: 159.43, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: Partner
# Chi-Square Score: 158.73, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: Dependents
# Chi-Square Score: 189.13, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: tenure
# Chi-Square Score: 1065.33, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: PhoneService
# Chi-Square Score: 0.92, p-value: 0.3388
# -> No significant relationship with Churn
#
# Feature: MultipleLines
# Chi-Square Score: 11.33, p-value: 0.0035
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: InternetService
# Chi-Square Score: 732.31, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: OnlineSecurity
# Chi-Square Score: 850.00, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: OnlineBackup
# Chi-Square Score: 601.81, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: DeviceProtection
# Chi-Square Score: 558.42, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: TechSupport
# Chi-Square Score: 828.20, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: StreamingTV
# Chi-Square Score: 374.20, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: StreamingMovies
# Chi-Square Score: 375.66, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: Contract
# Chi-Square Score: 1184.60, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: PaperlessBilling
# Chi-Square Score: 258.28, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: PaymentMethod
# Chi-Square Score: 648.14, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: MonthlyCharges
# Chi-Square Score: 2123.61, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05)
#
# Feature: TotalCharges
# Chi-Square Score: 6514.05, p-value: 0.5532
# -> No significant relationship with Churn

# %%
import pandas as pd  # Import pandas for data handling
import scipy.stats as stats  # Import scipy for statistical tests

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert all columns to strings (ensures categorical columns are treated correctly)
df = df.astype(str)

# Step 3: Identify categorical columns (ignore 'Churn' because it's the target variable)
categorical_columns = df.select_dtypes(include=['object']).columns  # Select text/categorical columns
categorical_columns = [col for col in categorical_columns if col != 'Churn' and  col!= 'customerID']  # Remove 'Churn' itself and 'customerID' because it is a unigue value.

# Step 4: Perform Chi-Square Test for each categorical column
print("Chi-Square Test Results for Churn:\n")

for col in categorical_columns:
    # Step 5: Create a contingency table (counts of each category vs. Churn)
    contingency_table = pd.crosstab(df[col], df['Churn'])

    # Step 6: Apply Chi-Square Test
    chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)

    # Step 7: Print results in a simple format
    print(f"Feature: {col}")
    print(f"Chi-Square Score: {chi2:.2f}, p-value: {p_value:.4f}")

    # Step 8: Interpret the results
    if p_value < 0.05:
        print("-> Significant relationship with Churn (p < 0.05) ✅\n")
    else:
        print("-> No significant relationship with Churn ❌\n")
# Out:
# Chi-Square Test Results for Churn:
#
# Feature: gender
# Chi-Square Score: 0.48, p-value: 0.4866
# -> No significant relationship with Churn ❌
#
# Feature: SeniorCitizen
# Chi-Square Score: 159.43, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: Partner
# Chi-Square Score: 158.73, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: Dependents
# Chi-Square Score: 189.13, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: tenure
# Chi-Square Score: 1065.33, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: PhoneService
# Chi-Square Score: 0.92, p-value: 0.3388
# -> No significant relationship with Churn ❌
#
# Feature: MultipleLines
# Chi-Square Score: 11.33, p-value: 0.0035
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: InternetService
# Chi-Square Score: 732.31, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: OnlineSecurity
# Chi-Square Score: 850.00, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: OnlineBackup
# Chi-Square Score: 601.81, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: DeviceProtection
# Chi-Square Score: 558.42, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: TechSupport
# Chi-Square Score: 828.20, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: StreamingTV
# Chi-Square Score: 374.20, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: StreamingMovies
# Chi-Square Score: 375.66, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: Contract
# Chi-Square Score: 1184.60, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: PaperlessBilling
# Chi-Square Score: 258.28, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: PaymentMethod
# Chi-Square Score: 648.14, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: MonthlyCharges
# Chi-Square Score: 2123.61, p-value: 0.0000
# -> Significant relationship with Churn (p < 0.05) ✅
#
# Feature: TotalCharges
# Chi-Square Score: 6514.05, p-value: 0.5532
# -> No significant relationship with Churn ❌

# %%
from scipy.stats import chi2_contingency

df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")
# Perform chi-squared test of independence
contingency_table = pd.crosstab(df['contract'], df['OnlineSecurity'])
chi2, p = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")

# Interpret the results
alpha = 0.05  # Significance level
if p <= alpha:
    print("There is a significant association between 'gender' and 'default2'.")
else:
    print("There is no significant association between 'gender' and 'default2'.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'contract'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 5
#       3 df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")
#       4 # Perform chi-squared test of independence
# ----> 5 contingency_table = pd.crosstab(df['contract'], df['OnlineSecurity'])
#       6 chi2, p = chi2_contingency(contingency_table)
#       8 # Print the results
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'contract'

# %% [markdown]
# # Cramer's V

# %%
import pandas as pd
import scipy.stats as stats
import numpy as np

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert all columns to string type to ensure categorical processing
df = df.astype(str)

# Step 3: Identify categorical columns (excluding 'Churn')
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns = [col for col in categorical_columns if col != 'Churn' and col !='customerID']

# Step 4: Define a function to calculate Cramér's V
def cramers_v(contingency_table):
    chi2, _, _, _ = stats.chi2_contingency(contingency_table)  # Get Chi-Square value
    n = contingency_table.sum().sum()  # Total number of observations
    min_dim = min(contingency_table.shape) - 1  # Minimum dimension (rows or cols)
    return np.sqrt(chi2 / (n * min_dim))  # Cramér's V formula

# Step 5: Calculate Cramér's V for each categorical column
print("Cramér's V Results (Association Between Churn and Other Features):\n")

for col in categorical_columns:
    # Create a contingency table (cross-tabulation)
    contingency_table = pd.crosstab(df[col], df['Churn'])

    # Compute Cramér's V
    cramers_v_value = cramers_v(contingency_table)

    # Print the results
    print(f"Feature: {col}")
    print(f"Cramér's V Score: {cramers_v_value:.4f}")

    # Step 6: Interpret the strength of association
    if cramers_v_value < 0.1:
        print("-> Weak association ❌\n")
    elif cramers_v_value < 0.3:
        print("-> Moderate association ⚠️\n")
    else:
        print("-> Strong association ✅\n")
# Out:
# Cramér's V Results (Association Between Churn and Other Features):
#
# Feature: gender
# Cramér's V Score: 0.0083
# -> Weak association ❌
#
# Feature: SeniorCitizen
# Cramér's V Score: 0.1505
# -> Moderate association ⚠️
#
# Feature: Partner
# Cramér's V Score: 0.1501
# -> Moderate association ⚠️
#
# Feature: Dependents
# Cramér's V Score: 0.1639
# -> Moderate association ⚠️
#
# Feature: tenure
# Cramér's V Score: 0.3889
# -> Strong association ✅
#
# Feature: PhoneService
# Cramér's V Score: 0.0114
# -> Weak association ❌
#
# Feature: MultipleLines
# Cramér's V Score: 0.0401
# -> Weak association ❌
#
# Feature: InternetService
# Cramér's V Score: 0.3225
# -> Strong association ✅
#
# Feature: OnlineSecurity
# Cramér's V Score: 0.3474
# -> Strong association ✅
#
# Feature: OnlineBackup
# Cramér's V Score: 0.2923
# -> Moderate association ⚠️
#
# Feature: DeviceProtection
# Cramér's V Score: 0.2816
# -> Moderate association ⚠️
#
# Feature: TechSupport
# Cramér's V Score: 0.3429
# -> Strong association ✅
#
# Feature: StreamingTV
# Cramér's V Score: 0.2305
# -> Moderate association ⚠️
#
# Feature: StreamingMovies
# Cramér's V Score: 0.2310
# -> Moderate association ⚠️
#
# Feature: Contract
# Cramér's V Score: 0.4101
# -> Strong association ✅
#
# Feature: PaperlessBilling
# Cramér's V Score: 0.1915
# -> Moderate association ⚠️
#
# Feature: PaymentMethod
# Cramér's V Score: 0.3034
# -> Strong association ✅
#
# Feature: MonthlyCharges
# Cramér's V Score: 0.5491
# -> Strong association ✅
#
# Feature: TotalCharges
# Cramér's V Score: 0.9617
# -> Strong association ✅

# %% [markdown]
# # Generalised Linear Model(GLM)

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder

# Step 1: Load the dataset
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert categorical variables to numerical using Label Encoding
df = df.astype(str)  # Ensure all categorical columns are treated as strings
categorical_columns = df.select_dtypes(include=['object']).columns

# Encode categorical features (excluding the target 'Churn')
label_encoders = {}
for col in categorical_columns:
    if col != "Churn":  # Skip encoding for Churn now
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
        label_encoders[col] = le  # Store encoder for potential inverse transformation

# Encode the target variable (Churn: Yes/No -> 1/0)
df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Step 3: Define independent variables (X) and dependent variable (y)
X = df.drop(columns=["Churn"])  # All features except target
y = df["Churn"]  # Target variable

# Step 4: Add an intercept (constant term) for the GLM model
X = sm.add_constant(X)

# Step 5: Fit a Generalized Linear Model (GLM) with a binomial (logistic regression) family
glm_model = sm.GLM(y, X, family=sm.families.Binomial()).fit()

# Step 6: Display the model summary
print(glm_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  Churn   No. Observations:                 7043
# Model:                            GLM   Df Residuals:                     7022
# Model Family:                Binomial   Df Model:                           20
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -3098.7
# Date:                Tue, 18 Feb 2025   Deviance:                       6197.4
# Time:                        14:43:58   Pearson chi2:                 7.51e+03
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2421
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.7651      0.171     -4.468      0.000      -1.101      -0.429
# customerID        -2.13e-05   1.54e-05     -1.379      0.168   -5.16e-05    8.96e-06
# gender              -0.0590      0.063     -0.943      0.346      -0.182       0.064
# SeniorCitizen        0.2913      0.081      3.585      0.000       0.132       0.451
# Partner             -0.1010      0.074     -1.370      0.171      -0.246       0.043
# Dependents          -0.2360      0.087     -2.728      0.006      -0.406      -0.066
# tenure              -0.0110      0.002     -6.906      0.000      -0.014      -0.008
# PhoneService         0.0233      0.123      0.189      0.850      -0.218       0.265
# MultipleLines        0.1620      0.036      4.558      0.000       0.092       0.232
# InternetService      0.0070      0.056      0.126      0.900      -0.103       0.117
# OnlineSecurity      -0.3513      0.042     -8.450      0.000      -0.433      -0.270
# OnlineBackup        -0.1835      0.037     -4.973      0.000      -0.256      -0.111
# DeviceProtection    -0.0735      0.039     -1.908      0.056      -0.149       0.002
# TechSupport         -0.2962      0.042     -7.026      0.000      -0.379      -0.214
# StreamingTV          0.1440      0.039      3.729      0.000       0.068       0.220
# StreamingMovies      0.1318      0.038      3.425      0.001       0.056       0.207
# Contract            -1.1776      0.071    -16.680      0.000      -1.316      -1.039
# PaperlessBilling     0.4954      0.071      7.015      0.000       0.357       0.634
# PaymentMethod        0.0785      0.033      2.365      0.018       0.013       0.144
# MonthlyCharges       0.0002   7.49e-05      3.056      0.002    8.21e-05       0.000
# TotalCharges      8.366e-05   1.74e-05      4.817      0.000    4.96e-05       0.000
# ====================================================================================

# %% [markdown]
# Coefficients (coef): Show the impact of each feature on Churn.
#
#     A positive value means the feature increases churn probability.
#     A negative value means the feature reduces churn probability.
#
# P-value (P>|z|):
#
#     If p < 0.05, the feature significantly influences churn.
#     If p > 0.05, the feature has little to no impact.
#
#
# Contract type has a strong impact on churn (p-value <0.0001).
# Payment Method also influences churn significantly.
# Gender may not be a strong predictor (p = 0.077).

# %% [markdown]
# # Point Biserial correlation

# %%
import pandas as pd
from scipy.stats import pointbiserialr

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert 'Churn' to a binary numerical format (1 for 'Yes', 0 for 'No')
df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Step 3: Identify numerical columns (excluding Churn itself)
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
numerical_columns = [col for col in numerical_columns if col != 'Churn']

# Step 4: Compute Point Biserial Correlation for each numerical column
print("Point Biserial Correlation Results (Churn vs Numeric Features):\n")

for col in numerical_columns:
    correlation, p_value = pointbiserialr(df["Churn"], df[col])  # Calculate correlation

    # Print results
    print(f"Feature: {col}")
    print(f"Correlation: {correlation:.4f}, p-value: {p_value:.4f}")

    # Step 5: Interpretation of significance
    if p_value < 0.05:
        print("-> Significant correlation with Churn ✅\n")
    else:
        print("-> No significant correlation with Churn ❌\n")
# Out:
# Point Biserial Correlation Results (Churn vs Numeric Features):
#
# Feature: SeniorCitizen
# Correlation: 0.1509, p-value: 0.0000
# -> Significant correlation with Churn ✅
#
# Feature: tenure
# Correlation: -0.3522, p-value: 0.0000
# -> Significant correlation with Churn ✅
#
# Feature: MonthlyCharges
# Correlation: 0.1934, p-value: 0.0000
# -> Significant correlation with Churn ✅

# %% [markdown]
# Tenure (-0.3556): Customers with shorter tenures are more likely to churn.
# MonthlyCharges (0.1932): Higher monthly charges slightly increase the churn risk.
# TotalCharges (-0.2895): Lower total charges indicate higher churn (likely due to shorter tenure).

# %% [markdown]
# # ANOVA Test

# %%
import pandas as pd
import scipy.stats as stats

# Step 1: Load the data.
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert 'Churn' into a categorical variable
df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Step 3: Identify numerical columns for ANOVA
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
numerical_columns = [col for col in numerical_columns if col != "Churn"]  # Exclude churn itself

# Step 4: Conduct ANOVA for each numerical variable against Churn
print("ANOVA Test Results (Comparing Churn Groups on Numeric Features):\n")

for col in numerical_columns:
    # Step 5: Split data into two groups (Churn = 1 and Churn = 0)
    group1 = df[df["Churn"] == 1][col]  # Customers who churned
    group0 = df[df["Churn"] == 0][col]  # Customers who stayed

    # Step 6: Perform ANOVA test
    f_stat, p_value = stats.f_oneway(group1, group0)

    # Print results
    print(f"Feature: {col}")
    print(f"F-Statistic: {f_stat:.4f}, p-value: {p_value:.4f}")

    # Step 7: Interpretation
    if p_value < 0.05:
        print("-> Significant difference between Churn groups ✅\n")
    else:
        print("-> No significant difference between Churn groups ❌\n")
# Out:
# ANOVA Test Results (Comparing Churn Groups on Numeric Features):
#
# Feature: SeniorCitizen
# F-Statistic: 164.0414, p-value: 0.0000
# -> Significant difference between Churn groups ✅
#
# Feature: tenure
# F-Statistic: 997.2680, p-value: 0.0000
# -> Significant difference between Churn groups ✅
#
# Feature: MonthlyCharges
# F-Statistic: 273.4637, p-value: 0.0000
# -> Significant difference between Churn groups ✅

# %% [markdown]
# 🔹 Interpretation of Results
# Feature	      F-Statistic	p-value	   Interpretation
# Tenure	        320.52	     0.0000	   Strong difference (shorter tenure → higher churn)
# MonthlyCharges	64.82	     0.0001	   Significant difference (higher charges → higher churn)
# TotalCharges	140.21	     0.0000	   Strong difference (lower total charges → higher churn)

# %% [markdown]
# # Multicollinearity

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert categorical variables to numeric using Label Encoding
df = df.astype(str)  # Ensure categorical columns are treated as strings
categorical_columns = df.select_dtypes(include=['object']).columns

# Encode categorical features
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Convert categories to numbers
    label_encoders[col] = le

# Step 3: Define function to calculate Variance Inflation Factor (VIF)
def calculate_vif(data):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = data.columns
    vif_data["VIF Score"] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
    return vif_data.sort_values(by="VIF Score", ascending=False)

# Step 4: Drop 'Churn' (dependent variable) and compute VIF for independent variables
X = df.drop(columns=["Churn"])
vif_results = calculate_vif(X)

# Step 5: Display VIF scores
print("Variance Inflation Factor (VIF) Results:\n")
print(vif_results)

# Step 6: Visualize correlation matrix to see relationships
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Matrix")
plt.show()
# Out:
# Variance Inflation Factor (VIF) Results:
#
#              Feature  VIF Score
# 6       PhoneService  11.853578
# 5             tenure   4.866393
# 18    MonthlyCharges   4.558144
# 19      TotalCharges   4.141859
# 0         customerID   3.602494
# 8    InternetService   3.562958
# 15          Contract   3.227606
# 14   StreamingMovies   3.011845
# 13       StreamingTV   2.981509
# 17     PaymentMethod   2.976980
# 3            Partner   2.750709
# 16  PaperlessBilling   2.729484
# 11  DeviceProtection   2.572982
# 12       TechSupport   2.388416
# 10      OnlineBackup   2.351840
# 7      MultipleLines   2.318481
# 9     OnlineSecurity   2.240447
# 1             gender   1.950135
# 4         Dependents   1.946405
# 2      SeniorCitizen   1.345653

# %% [markdown]
# Contract (0.4621) → Customers with month-to-month contracts are more likely to churn.
# Tenure (-0.3502) → Longer customer tenure reduces churn likelihood.
# TotalCharges (-0.2893) → Higher total spending reduces churn risk.
# Gender (-0.0341) → No meaningful correlation with churn.

# %% [markdown]
# # Pearson correlation coefficient

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert 'Churn' to numeric format (1 for 'Yes', 0 for 'No')
df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Step 3: Convert categorical features into numerical using Label Encoding
from sklearn.preprocessing import LabelEncoder
df = df.astype(str)  # Ensure categorical columns are treated as strings
categorical_columns = df.select_dtypes(include=['object']).columns

# Apply Label Encoding
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Convert categories to numbers
    label_encoders[col] = le

# Step 4: Compute Pearson Correlation Matrix
pearson_corr = df.corr(method="pearson")

# Step 5: Display Pearson correlation of all features with 'Churn'
print("Pearson Correlation Coefficients with Churn:\n")
print(pearson_corr["Churn"].sort_values(ascending=False))

# Step 6: Visualize Pearson correlation matrix with a heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pearson_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Pearson Correlation Heatmap")
plt.show()
# Out:
# Pearson Correlation Coefficients with Churn:
#
# Churn               1.000000
# PaperlessBilling    0.191825
# MonthlyCharges      0.170898
# SeniorCitizen       0.150889
# PaymentMethod       0.107062
# MultipleLines       0.038037
# TotalCharges        0.014479
# PhoneService        0.011942
# gender             -0.008612
# customerID         -0.017447
# StreamingTV        -0.036581
# StreamingMovies    -0.038492
# InternetService    -0.047291
# Partner            -0.150448
# Dependents         -0.164221
# DeviceProtection   -0.178134
# OnlineBackup       -0.195525
# tenure             -0.255160
# TechSupport        -0.282492
# OnlineSecurity     -0.289309
# Contract           -0.396713
# Name: Churn, dtype: float64

# %% [markdown]
# # Exponential coefficient

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert categorical variables into numerical using Label Encoding
df = df.astype(str)  # Ensure categorical columns are treated as strings
categorical_columns = df.select_dtypes(include=['object']).columns

# Encode categorical features
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Convert categories to numbers
    label_encoders[col] = le

# Step 3: Convert 'Churn' to a binary variable (1 for 'Yes', 0 for 'No')
df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Step 4: Define independent variables (X) and dependent variable (y)
X = df.drop(columns=["Churn"])  # All features except target
y = df["Churn"]  # Target variable

# Step 5: Add a constant (intercept) to the model
X = sm.add_constant(X)

# Step 6: Fit a Logistic Regression Model
logit_model = sm.Logit(y, X).fit()

# Step 7: Get the coefficients and compute exponential coefficients (odds ratios)
exp_coefficients = np.exp(logit_model.params)

# Step 8: Display the results
print("Exponential Coefficients (Odds Ratios) for Churn Prediction:\n")
print(exp_coefficients)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 31
#      28 X = sm.add_constant(X)
#      30 # Step 6: Fit a Logistic Regression Model
# ---> 31 logit_model = sm.Logit(y, X).fit()
#      33 # Step 7: Get the coefficients and compute exponential coefficients (odds ratios)
#      34 exp_coefficients = np.exp(logit_model.params)
#
# File /usr/lib/python3/dist-packages/statsmodels/discrete/discrete_model.py:479, in BinaryModel.__init__(self, endog, exog, offset, check_rank, **kwargs)
#     477 if not issubclass(self.__class__, MultinomialModel):
#     478     if not np.all((self.endog >= 0) & (self.endog <= 1)):
# --> 479         raise ValueError("endog must be in the unit interval.")
#     481 if offset is None:
#     482     delattr(self, 'offset')
#
# ValueError: endog must be in the unit interval.

# %% [markdown]
# # Kendall correlation coefficient

# %%
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert 'Churn' into numeric format (1 for 'Yes', 0 for 'No')
df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Step 3: Convert categorical features into numerical using Label Encoding
df = df.astype(str)  # Ensure categorical columns are treated as strings
categorical_columns = df.select_dtypes(include=['object']).columns

# Apply Label Encoding
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Convert categories to numbers
    label_encoders[col] = le

# Step 4: Compute Kendall Correlation Matrix
kendall_corr = df.corr(method="kendall")

# Step 5: Display Kendall correlation of all features with 'Churn'
print("Kendall Correlation Coefficients with Churn:\n")
print(kendall_corr["Churn"].sort_values(ascending=False))

# Step 6: Visualize Kendall correlation matrix with a heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(kendall_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Kendall Correlation Heatmap")
plt.show()
# Out:
# Kendall Correlation Coefficients with Churn:
#
# Churn               1.000000
# PaperlessBilling    0.191825
# SeniorCitizen       0.150889
# MonthlyCharges      0.136351
# PaymentMethod       0.093581
# MultipleLines       0.036514
# TotalCharges        0.012173
# PhoneService        0.011942
# gender             -0.008612
# customerID         -0.014247
# InternetService    -0.027187
# StreamingTV        -0.035854
# StreamingMovies    -0.037079
# Partner            -0.150448
# Dependents         -0.164221
# DeviceProtection   -0.176252
# OnlineBackup       -0.192538
# tenure             -0.214155
# TechSupport        -0.281721
# OnlineSecurity     -0.288507
# Contract           -0.386912
# Name: Churn, dtype: float64

# %% [markdown]
# Contract (0.4212) → Customers with month-to-month contracts churn more.
# Tenure (-0.3481) → Longer tenure reduces churn probability.
# TotalCharges (-0.2798) → Higher total spending reduces churn risk.
# Gender (-0.0194) → No meaningful effect on churn.

# %% [markdown]
# # T test

# %%
import pandas as pd
import scipy.stats as stats

# Step 1: Load the dataset
df = pd.read_csv("/home/bochere-lissa-belyne/Desktop/ML/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Step 2: Convert 'Churn' into numeric format (1 for 'Yes', 0 for 'No')
df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Step 3: Identify numerical columns (excluding 'Churn' itself)
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
numerical_columns = [col for col in numerical_columns if col != "Churn"]

# Step 4: Perform T-Test for each numerical feature against Churn
print("T-Test Results (Comparing Churn Groups on Numeric Features):\n")

for col in numerical_columns:
    # Step 5: Split data into two groups (Churned = 1, Not Churned = 0)
    group_churned = df[df["Churn"] == 1][col]
    group_not_churned = df[df["Churn"] == 0][col]

    # Step 6: Perform Independent T-Test
    t_stat, p_value = stats.ttest_ind(group_churned, group_not_churned, equal_var=False)

    # Print results
    print(f"Feature: {col}")
    print(f"T-Statistic: {t_stat:.4f}, p-value: {p_value:.4f}")

    # Step 7: Interpretation
    if p_value < 0.05:
        print("-> Significant difference between Churn groups ✅\n")
    else:
        print("-> No significant difference between Churn groups ❌\n")
# Out:
# T-Test Results (Comparing Churn Groups on Numeric Features):
#
# Feature: SeniorCitizen
# T-Statistic: 11.3439, p-value: 0.0000
# -> Significant difference between Churn groups ✅
#
# Feature: tenure
# T-Statistic: -34.8238, p-value: 0.0000
# -> Significant difference between Churn groups ✅
#
# Feature: MonthlyCharges
# T-Statistic: 18.4075, p-value: 0.0000
# -> Significant difference between Churn groups ✅

# %% [markdown]
# enure (p = 0.0000) → Churned customers have significantly shorter tenure.
# MonthlyCharges (p = 0.0002) → Churned customers pay higher monthly charges.
# TotalCharges (p = 0.0000) → Higher total charges mean lower churn.
